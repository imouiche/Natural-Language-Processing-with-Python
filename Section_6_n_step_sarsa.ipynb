# %% [markdown]
# <div style="text-align:center">
#     <h1>
#         n-step SARSA
#     </h1>
# </div>
#
# <br><br>
#
# <div style="text-align:center">
#     In this notebook we are going to combine the temporal difference method SARSA with n-step bootstrapping. The resulting algorithm is called n-step SARSA and uses the following target for the updates:
# </div>
#
# \begin{equation}
# \hat G_t = R_{t+1} + \gamma R_{t+2} + \cdots + \gamma^{n-1} R_{n} + \gamma Q(S_n, A_n)
# \end{equation}
#
# <br>
#
# <div style="text-align:center">
#     This method follows an on-policy strategy, in which the same policy that is optimized is responsible for exploring the environment.
# </div>
#
#
# <br>
#
#
#
# <br><br>
# <div style="text-align:center">
#     <b>This notebook belongs to section 6 of the course "Reinforcement Learning: beginner to master".</b>
#     <br><br>
#     <a href="https://www.udemy.com">Reinforcement Learning: beginner to master</a> (English)
#     <br>
#     <a href="https://www.udemy.com">Reinforcement Learning: de principiante a maestro</a> (Spanish)
# </div>
#
# <br>
#
# <table style="width:35%">
#   <tr style="background-color: transparent">
#     <td style="width: 45%">
#         <a target="_parent" href="https://www.evlabs.io" style="float: center">
#             <img src="img/evlabs-square.png" width="75"/>
#         </a>
#     </td>
#     <td valign="bottom">
#         <a target="_parent" href="https://www.youtube.com/channel/UCksRNSzWuMV5IfdrPlglqqw">
#             <img src="img/YouTube.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://www.linkedin.com/company/evlabs">
#             <img src="img/LinkedIn.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://twitter.com/evelabs">
#             <img src="img/Twitter.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://github.com/escape-velocity-labs/">
#             <img src="img/GitHub.png" width="35"/>
#         </a>
#     </td>
#
#   </tr>
#   <tr style="background-color: transparent">
#     <th style="text-align: center; width: 70%">Escape Velocity Labs</th>
#   </tr>
#
# </table>
#
# <br>

# %% [markdown]
# ## Import the necessary software libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt

from envs import Maze
from utils import plot_policy, plot_action_values, test_agent

# %% [markdown]
# ## Create the environment, value table and policy

# %% [markdown]
# #### Create the environment

# %%
env = Maze()

# %% [markdown]
# #### Create the $Q(s, a)$ table

# %%
action_values = np.zeros(shape=(5, 5, 4))

# %% [markdown]
# #### Create the policy $\pi(s)$

# %%
def policy(state, epsilon=0.):
    if np.random.random() < epsilon:
        return np.random.randint(4)
    else:
        av = action_values[state]
        return np.random.choice(np.flatnonzero(av == av.max()))

# %% [markdown]
# #### Plot the value table $Q(s,a)$

# %%
plot_action_values(action_values)

# %% [markdown]
# #### Plot the policy

# %%
plot_policy(action_values, env.render(mode='rgb_array'))
# Out:
# D:\Users\apytl\AppData\Anaconda3\envs\bmrl\lib\site-packages\pyglet\image\codecs\wic.py:406: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))

# %% [markdown]
# ## Implement the algorithm
#
# </br>
#
# ![Screenshot%202021-03-05%20at%2014.35.21.png](attachment:Screenshot%202021-03-05%20at%2014.35.21.png)

# %%
def n_step_sarsa(action_values, policy, episodes, alpha=.1, gamma=.99, epsilon=0.2, n=8):
    
    for episode in range(1, episodes + 1):
        state = env.reset()
        action = policy(state, epsilon)
        transition = [] #store the state transition we'll use to update the q-value
        done = False
        t = 0  # t will tell us the moment in time it is experiencing inside the episode 
        
        while t-n < len(transition):
            
            # if the task is not done, then execute an action in the env
            if not done:
                next_state, reward, done, _ = env.step(action)
                next_action = policy(next_state, epsilon)
                transition.append([state, action, reward])
            
            #update q-value
            if t >= n:
                # G = r1 + gamma*r2 + gamma^2 * r2 + ... gamma^n * Q(Sn, An)
                G = (1 - done) * action_values[next_state][next_action] #(1 - done) is a trick consider the case 
                #when we reach the terminal where we know the estimate is zero 
                for state_t, action_t, reward_t in reversed(transition[t-n:]):
                    G = reward_t + gamma * G
    
                #update rule
                action_values[state_t][action_t] += alpha * (G - action_values[state_t][action_t])
           
            t += 1
            state =  next_state
            action =  next_action

# %%
n_step_sarsa(action_values, policy, 1000)

# %% [markdown]
# ## Show results

# %% [markdown]
# #### Show resulting value table $Q(s, a)$

# %%
plot_action_values(action_values)

# %% [markdown]
# #### Show resulting policy $\pi(\cdot|s)$

# %%
plot_policy(action_values, env.render(mode='rgb_array'))

# %% [markdown]
# #### Test the resulting agent

# %%
test_agent(env, policy) # we can see that our estimate is capable of finding the exit

# %% [markdown]
# ## Resources

# %% [markdown]
# [[1] Reinforcement Learning: An Introduction. Ch. 7: n-step bootstrapping](https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf)
